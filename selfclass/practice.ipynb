# %%
import matplotlib.pyplot as plt
import random

data2=[]
for i in range(1000):
 data2.append(random.normalvariate(0,10))

plt.title("Histogram")
plt.hist(data2, bins=50)
plt.show()

# %%
import matplotlib.pyplot as plt
import random
his=[]
for i in range(10):
    his.append(random.uniform(0,10))

plt.hist(his, bins=10)
plt.show()
