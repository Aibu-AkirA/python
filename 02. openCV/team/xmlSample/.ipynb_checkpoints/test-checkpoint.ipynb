# %%
import numpy as np
import cv2 as cv


#　顔とめを認識するXMLファイルを呼び出す。
face_cascade = cv.CascadeClassifier('haarcascade_frontface.xml')
eye_cascade = cv.CascadeClassifier('mouth.xml')


img1 = cv.imread('sachin.jpg')
gray1 = cv.cvtColor(img1, cv.COLOR_BGR2GRAY)

img2 = cv.imread('sachin2.jpg')
gray2 = cv.cvtColor(img2, cv.COLOR_BGR2GRAY)

img3 = cv.imread('sachin3.jpg')
gray3 = cv.cvtColor(img3, cv.COLOR_BGR2GRAY)



# 顔の認識. 
faces1 = face_cascade.detectMultiScale(gray1, 1.3, 5)
faces2 = face_cascade.detectMultiScale(gray2, 1.3, 5)
faces3 = face_cascade.detectMultiScale(gray3, 1.3, 5)

#顔の座標をRETURNする。
for (x,y,w,h) in faces1:

    # 顔を表示。
    cv.rectangle(img1,(x,y),(x+w,y+h),(255,0,0),2)

    #　目は顔の中にあるので顔の中でやる
    roi_gray1 = gray1[y:y+h, x:x+w]
    roi_color1 = img1[y:y+h, x:x+w]

    # 目の認識.
    eyes1 = eye_cascade.detectMultiScale(roi_gray1)

    # 目の座標をRETURNする. 
    for (ex,ey,ew,eh) in eyes1:
        # 顔を表示 
        cv.rectangle(roi_color1,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

for (x,y,w,h) in faces2:

    cv.rectangle(img2,(x,y),(x+w,y+h),(255,0,0),2)
 
    roi_gray2 = gray2[y:y+h, x:x+w]
    roi_color2 = img2[y:y+h, x:x+w]

    eyes2 = eye_cascade.detectMultiScale(roi_gray2)
 
    for (ex,ey,ew,eh) in eyes2:
        cv.rectangle(roi_color2,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        
for (x,y,w,h) in faces3:

    cv.rectangle(img3,(x,y),(x+w,y+h),(255,0,0),2)
 
    roi_gray3 = gray3[y:y+h, x:x+w]
    roi_color3 = img3[y:y+h, x:x+w]

    eyes3 = eye_cascade.detectMultiScale(roi_gray3)
 
    for (ex,ey,ew,eh) in eyes3:
        cv.rectangle(roi_color3,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

# 얼굴과 눈 검출 결과를 화면에 보여줍니다.
cv.imshow('img1',img1)
cv.imshow('img2',img2)
cv.imshow('img3',img3)
cv.waitKey(0)

cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv



face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')
#face_cascade = cv.CascadeClassifier('haarcascade_fullbody.xml')


img1 = cv.imread('Sample1.jpg')
gray1 = cv.cvtColor(img1, cv.COLOR_BGR2GRAY)
img2 = cv.imread('Sample2.jpg')
gray2 = cv.cvtColor(img2, cv.COLOR_BGR2GRAY)
img3 = cv.imread('Sample3.jpg')
gray3 = cv.cvtColor(img3, cv.COLOR_BGR2GRAY)
img4 = cv.imread('Sample4.jpg')
gray4 = cv.cvtColor(img4, cv.COLOR_BGR2GRAY)
img5 = cv.imread('Sample5.jpg')
gray5 = cv.cvtColor(img5, cv.COLOR_BGR2GRAY)
img6 = cv.imread('Sample6.jpg')
gray6 = cv.cvtColor(img6, cv.COLOR_BGR2GRAY)
img7 = cv.imread('Sample7.jpg')
gray7 = cv.cvtColor(img7, cv.COLOR_BGR2GRAY)
img8 = cv.imread('Sample8.jpg')
gray8 = cv.cvtColor(img8, cv.COLOR_BGR2GRAY)
img9 = cv.imread('Sample9.jpg')
gray9 = cv.cvtColor(img9, cv.COLOR_BGR2GRAY)
img10 = cv.imread('Sample10.jpg')
gray10 = cv.cvtColor(img10, cv.COLOR_BGR2GRAY)

faces1 = face_cascade.detectMultiScale(gray1, 1.3, 5)
faces2 = face_cascade.detectMultiScale(gray2, 1.3, 5)
faces3 = face_cascade.detectMultiScale(gray3, 1.3, 5)
faces4 = face_cascade.detectMultiScale(gray4, 1.3, 5)
faces5 = face_cascade.detectMultiScale(gray5, 1.3, 5)
faces6 = face_cascade.detectMultiScale(gray6, 1.3, 5)
faces7 = face_cascade.detectMultiScale(gray7, 1.3, 5)
faces8 = face_cascade.detectMultiScale(gray8, 1.3, 5)
faces9 = face_cascade.detectMultiScale(gray9, 1.3, 5)
faces10 = face_cascade.detectMultiScale(gray10, 1.3, 5)

for (x,y,w,h) in faces1:

    cv.rectangle(img1,(x,y),(x+w,y+h),(255,0,0),2)

for (x,y,w,h) in faces2:

    cv.rectangle(img2,(x,y),(x+w,y+h),(255,0,0),2) 

for (x,y,w,h) in faces3:

    cv.rectangle(img3,(x,y),(x+w,y+h),(255,0,0),2)

for (x,y,w,h) in faces4:

    cv.rectangle(img4,(x,y),(x+w,y+h),(255,0,0),2)

for (x,y,w,h) in faces5:

    cv.rectangle(img5,(x,y),(x+w,y+h),(255,0,0),2)

for (x,y,w,h) in faces6:

    cv.rectangle(img6,(x,y),(x+w,y+h),(255,0,0),2)

for (x,y,w,h) in faces7:

    cv.rectangle(img7,(x,y),(x+w,y+h),(255,0,0),2)

for (x,y,w,h) in faces8:

    cv.rectangle(img8,(x,y),(x+w,y+h),(255,0,0),2)

for (x,y,w,h) in faces9:

    cv.rectangle(img9,(x,y),(x+w,y+h),(255,0,0),2)

for (x,y,w,h) in faces10:

    cv.rectangle(img10,(x,y),(x+w,y+h),(255,0,0),2)

cv.imshow('img1',img1)
cv.imshow('img2',img2)
cv.imshow('img3',img3)
cv.imshow('img4',img4)
cv.imshow('img5',img5)
cv.imshow('img6',img6)
cv.imshow('img7',img7)
cv.imshow('img8',img8)
cv.imshow('img9',img9)
cv.imshow('img10',img10)


cv.waitKey(0)

cv.destroyAllWindows()

# %%
import numpy as np
import cv2

cv2.namedWindow('image', cv2.WINDOW_NORMAL)

#Load the Image
imgo = cv2.imread('Sample9.jpg')
height, width = imgo.shape[:2]

#Create a mask holder
mask = np.zeros(imgo.shape[:2],np.uint8)

#Grab Cut the object
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)

#Hard Coding the Rect The object must lie within this rect.
rect = (10,10,width-30,height-30)
cv2.grabCut(imgo,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)
mask = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img1 = imgo*mask[:,:,np.newaxis]

#Get the background
background = imgo - img1

#Change all pixels in the background that are not black to white
background[np.where((background > [0,0,0]).all(axis = 2))] = [255,255,255]

#Add the background and the image
final = background + img1

#To be done - Smoothening the edges

cv2.imshow('image', final )

k = cv2.waitKey(0)

if k==27:
       cv2.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv



face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')


img2 = cv.imread('Sample2.jpg')
gray2 = cv.cvtColor(img2, cv.COLOR_BGR2GRAY)
img10 = cv.imread('Sample10.jpg')
gray10 = cv.cvtColor(img10, cv.COLOR_BGR2GRAY)

faces2 = face_cascade.detectMultiScale(gray2, 1.3, 5)
faces10 = face_cascade.detectMultiScale(gray10, 1.3, 5)


for (x,y,w,h) in faces2:
    cv.rectangle(img2,(x,y),(x+w,y+h),(255,0,0),2) 
for (x,y,w,h) in faces10:
    cv.rectangle(img10,(x,y),(x+w,y+h),(255,0,0),2)

cv.imshow('img2',img2)
cv.imshow('img10',img10)

print(faces2)
print(faces2[0][1])
print(faces10)
print(faces10[0][2])
cv.waitKey(0)

cv.destroyAllWindows()
# Out:
# [[253  78 142 142]]
# 78
# [[286 118 131 131]]
# 131
