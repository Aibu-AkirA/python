# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

while(1):
    
    _, frame= cap.read()
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    
    imgSize = np.shape(frame)
    
    mosaic_rate = 20
    all_img = cv2.resize(frame, (imgSize[1]//mosaic_rate, imgSize[0]//mosaic_rate))
    all_img = cv2.resize(all_img, (imgSize[1], imgSize[0]), interpolation=cv2.INTER_AREA)

    for (x,y,w,h) in faces:
        roi = frame[y:y+h, x:x+w]
        all_img[y:y+h, x:x+h] = roi
    
    
    cv2.imshow('all_img ',all_img)
    
    k = cv2.waitKey(5) & 0xFF
    k2 = cv2.waitKey(5)
    if k == 27:
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
_0, frame0= cap.read()
imgSize = np.shape(frame)

#先にイメージをロードする 
all_img = cv2.imread('.jpg')

#----------------------------------
#ここでall_imgのサイズを調節
#----------------------------------

while(1):
    
    _, frame= cap.read()
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    for (x,y,w,h) in faces:
        roi = frame[y:y+h, x:x+w]
        all_img[y:y+h, x:x+h] = roi
    
    
    cv2.imshow('all_img ',all_img)
    
    k = cv2.waitKey(5) & 0xFF
    k2 = cv2.waitKey(5)
    if k == 27:
        break
        
cap.release()
cv2.destroyAllWindows()
